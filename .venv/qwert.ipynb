# %%
import csv

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Елдос\PyCharmMiscProject\.venv

# %%
print(os.listdir())
# Out:
# ['.venv', 'Lib', 'qwert.ipynb']

# %%
with open("synthetic_data", "r") as file:
    csv_data = csv.reader(file)
    data = list(csv_data)
    for row in data:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with open("synthetic_data", "r") as file:
#       2     csv_data = csv.reader(file)
#       3     data = list(csv_data)
#
# File ~\PyCharmMiscProject\.venv\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'synthetic_data'
