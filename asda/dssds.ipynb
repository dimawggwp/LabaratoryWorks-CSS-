# %%
from sys import displayhook

import pandas as pd
import numpy as np
df = pd.read_excel("catalog_products.xlsx")

print("Форма DataFrame:", df.shape)
print("Типы данных: ", df.dtypes)
print("Пропуски: ", df.isnull().sum())
print("Первые 5 строк: ", df.head())
# Out:
# Форма DataFrame: (10000, 50)
# Типы данных:  col_1       str
# col_2     int64
# col_3     int64
# col_4       str
# col_5     int64
# col_6     int64
# col_7       str
# col_8     int64
# col_9     int64
# col_10      str
# col_11    int64
# col_12    int64
# col_13      str
# col_14    int64
# col_15    int64
# col_16      str
# col_17    int64
# col_18    int64
# col_19      str
# col_20    int64
# col_21    int64
# col_22      str
# col_23    int64
# col_24    int64
# col_25      str
# col_26    int64
# col_27    int64
# col_28      str
# col_29    int64
# col_30    int64
# col_31      str
# col_32    int64
# col_33    int64
# col_34      str
# col_35    int64
# col_36    int64
# col_37      str
# col_38    int64
# col_39    int64
# col_40      str
# col_41    int64
# col_42    int64
# col_43      str
# col_44    int64
# col_45    int64
# col_46      str
# col_47    int64
# col_48    int64
# col_49      str
# col_50    int64
# dtype: object
# Пропуски:  col_1     0
# col_2     0
# col_3     0
# col_4     0
# col_5     0
# col_6     0
# col_7     0
# col_8     0
# col_9     0
# col_10    0
# col_11    0
# col_12    0
# col_13    0
# col_14    0
# col_15    0
# col_16    0
# col_17    0
# col_18    0
# col_19    0
# col_20    0
# col_21    0
# col_22    0
# col_23    0
# col_24    0
# col_25    0
# col_26    0
# col_27    0
# col_28    0
# col_29    0
# col_30    0
# col_31    0
# col_32    0
# col_33    0
# col_34    0
# col_35    0
# col_36    0
# col_37    0
# col_38    0
# col_39    0
# col_40    0
# col_41    0
# col_42    0
# col_43    0
# col_44    0
# col_45    0
# col_46    0
# col_47    0
# col_48    0
# col_49    0
# col_50    0
# dtype: int64
# Первые 5 строк:      col_1  col_2  col_3        col_4  col_5  col_6     col_7  col_8  col_9  \
# 0    Home    762    303  Electronics     49    348  Clothing    206    123
# 1  Sports    190     34       Sports    107     99  Clothing    836    775
# 2   Books    711      2         Home     93    876      Home    868     69
# 3  Sports    484    362        Books    636    361      Home    897    111
# 4  Sports    733    195         Home    829    937  Clothing    428    871
#
#         col_10  ...  col_41  col_42    col_43  col_44  col_45       col_46  \
# 0       Sports  ...     676     471      Home     511     424  Electronics
# 1  Electronics  ...     700     696     Books     329     677  Electronics
# 2        Books  ...     418     596      Home     781     622  Electronics
# 3     Clothing  ...     620     357      Home     811     240     Clothing
# 4         Home  ...     740     845  Clothing     272     143  Electronics
#
#    col_47  col_48       col_49  col_50
# 0     511     484       Sports     643
# 1     427     348         Home     603
# 2     964     339       Sports      95
# 3     427     313  Electronics     593
# 4     647     784       Sports      44
#
# [5 rows x 50 columns]

# %%
#2
numeric_cols = [f"col_{i}" for i in range(2, 12)]

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    df[col].fillna(df[col].mean(), inplace=True)

print("Проауски:", df[numeric_cols].isnull().sum())
# Out:
# Проверка пропусков после обработки: col_2         0
# col_3         0
# col_4     10000
# col_5         0
# col_6         0
# col_7     10000
# col_8         0
# col_9         0
# col_10    10000
# col_11        0
# dtype: int64
# C:\Users\Елдос\AppData\Local\Temp\ipykernel_8388\2547491530.py:7: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
#3
df["total_value"] = df["col_2"] * df["col_3"]
df["double_stock"] = df["col_4"] * 2
df["log_price"] = np.log(df["col_2"])
print(df[["total_value","double_stock","log_price"]].head())
# Out:
#    total_value  double_stock  log_price
# 0       230886           NaN   6.635947
# 1         6460           NaN   5.247024
# 2         1422           NaN   6.566672
# 3       175208           NaN   6.182085
# 4       142935           NaN   6.597146

# %%
#4
electronics_expensive = df[
    (df["col_2"] > 500) & (df["col_7"] == "Electronics")
]
print("Electronics дорогие: ", electronics_expensive.head())
# Out:
# 'Electronics дорогие: '
# Empty DataFrame
# Columns: [col_1, col_2, col_3, col_4, col_5, col_6, col_7, col_8, col_9, col_10, col_11, col_12, col_13, col_14, col_15, col_16, col_17, col_18, col_19, col_20, col_21, col_22, col_23, col_24, col_25, col_26, col_27, col_28, col_29, col_30, col_31, col_32, col_33, col_34, col_35, col_36, col_37, col_38, col_39, col_40, col_41, col_42, col_43, col_44, col_45, col_46, col_47, col_48, col_49, col_50, total_value, double_stock, log_price]
# Index: []
#
# [0 rows x 53 columns]

# %%
#5
grouped = df.groupby("col_7").agg(
    mean_price=("col_2", "mean"),
    max_price=("col_2", "max"),
    total_quantity=("col_3", "sum")
).reset_index()
print("Группировка: ", grouped.head())
# Out:
# Группировка:  Empty DataFrame
# Columns: [col_7, mean_price, max_price, total_quantity]
# Index: []

# %%
#6
stats = pd.DataFrame({
    "column": numeric_cols,
    "mean": [df[col].mean() for col in numeric_cols],
    "median": [df[col].median() for col in numeric_cols],
    "std": [df[col].std() for col in numeric_cols],
})

print("Стата: ", stats)
# Out:
# Стата:     column      mean  median         std
# 0   col_2  503.1608   509.0  289.808030
# 1   col_3  500.4676   502.5  288.052132
# 2   col_4       NaN     NaN         NaN
# 3   col_5  494.9370   493.0  290.634660
# 4   col_6  500.0842   502.0  287.772049
# 5   col_7       NaN     NaN         NaN
# 6   col_8  500.1320   498.0  287.280092
# 7   col_9  494.8945   488.0  288.756643
# 8  col_10       NaN     NaN         NaN
# 9  col_11  499.8112   501.0  287.426535

# %%
#7
mean_price = df["col_2"].mean()
std_price = df["col_2"].std()

anomalies = df[df["col_2"] > mean_price + 3 * std_price]
print("Аномалии: ", anomalies.head())
# Out:
# Аномалии:
#  Empty DataFrame
# Columns: [col_1, col_2, col_3, col_4, col_5, col_6, col_7, col_8, col_9, col_10, col_11, col_12, col_13, col_14, col_15, col_16, col_17, col_18, col_19, col_20, col_21, col_22, col_23, col_24, col_25, col_26, col_27, col_28, col_29, col_30, col_31, col_32, col_33, col_34, col_35, col_36, col_37, col_38, col_39, col_40, col_41, col_42, col_43, col_44, col_45, col_46, col_47, col_48, col_49, col_50, total_value, double_stock, log_price]
# Index: []
#
# [0 rows x 53 columns]

# %%
#8
corr_matrix = df[numeric_cols].corr()
print("Коррел: ", corr_matrix)
# Out:
# Коррел:             col_2     col_3  col_4     col_5     col_6  col_7     col_8  \
# col_2   1.000000 -0.006128    NaN -0.002368 -0.004579    NaN  0.019838
# col_3  -0.006128  1.000000    NaN  0.020303  0.004545    NaN  0.014136
# col_4        NaN       NaN    NaN       NaN       NaN    NaN       NaN
# col_5  -0.002368  0.020303    NaN  1.000000  0.022725    NaN  0.015310
# col_6  -0.004579  0.004545    NaN  0.022725  1.000000    NaN -0.005012
# col_7        NaN       NaN    NaN       NaN       NaN    NaN       NaN
# col_8   0.019838  0.014136    NaN  0.015310 -0.005012    NaN  1.000000
# col_9  -0.008986  0.004623    NaN  0.013237  0.002743    NaN -0.008199
# col_10       NaN       NaN    NaN       NaN       NaN    NaN       NaN
# col_11 -0.006885  0.002812    NaN -0.000047 -0.019907    NaN  0.002730
#
#            col_9  col_10    col_11
# col_2  -0.008986     NaN -0.006885
# col_3   0.004623     NaN  0.002812
# col_4        NaN     NaN       NaN
# col_5   0.013237     NaN -0.000047
# col_6   0.002743     NaN -0.019907
# col_7        NaN     NaN       NaN
# col_8  -0.008199     NaN  0.002730
# col_9   1.000000     NaN  0.017898
# col_10       NaN     NaN       NaN
# col_11  0.017898     NaN  1.000000
